# %%
import pandas as pd
import numpy as np
from scipy.signal import savgol_filter
from matplotlib import pyplot as plt
energy = pd.read_table('./m8B0Ustar1ak0.05/budgetWaterwind.dat', delimiter = ' ')

# %% [markdown]
# E = KE + GPE <br>
# $\zeta$ = dE/dt * 1/E

# %%
# plot the energy 
total = energy.ke + energy.gpe
growth_rate = np.gradient(total, energy.t) / total
plt.plot(energy.t, total/total[0])
plt.legend(['energy growth'], loc = 'upper left')
plt.xlabel('time')
plt.ylabel('ke+gpe')
plt.show()

# %%
# plot the energy growth 
# growth_rate_hat is the smoothed growth rate curve
growth_rate_hat = savgol_filter(growth_rate, 1001, 3)
plt.plot(energy.t[1000:], growth_rate_hat[1000:])
plt.xlabel('time')
plt.ylabel('growth rate')
plt.show()

# %%
field = pd.read_table('./m8B0Ustar1ak0.05/field10', delimiter = ' ')
slope = np.gradient(field['u.x'], field['y']) # first order derivative
curvature = np.gradient(slope, field['y']) # second order derivative

# %% [markdown]
# subplot: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplots.html

# %%
slope_hat = savgol_filter(slope, 101, 3)
curvature_hat = savgol_filter(curvature, 101, 3)
fig, axes = plt.subplots(1, 3, sharey='row')
axes[0].plot(field['u.x'], field['y'])
axes[1].plot(slope_hat, field['y'])
axes[2].plot(curvature_hat, field['y'])
plt.show()

# %%
# Transform np array curvature into pd DataFrame field_curv and the concatenate
# Not sure if should use curvature_hat or curvature
field_curv = pd.DataFrame(curvature_hat, columns = ['curv'])
# Notice: don't run this multiple times
field = pd.concat([field, field_curv], axis=1)

# %%
# Find the points at the interface
field_interface = field[field.pos != 1.000000e+30]
# define an small quantity eps, get the points with u.x close to wave speed c = 1 within the tolerance of eps 
# as field_cl (critical layer)
eps = 0.01
field_cl = field[abs((field['u.x']-1)) < eps]
# Plot the two curves 
plt.plot(field_cl.x, field_cl.y)
plt.plot(field_interface.x, field_interface.pos)
plt.show()

# %%
field_cl
# Out:
#                x         y       u.x           pos         curv         curv  \
# 17190  -0.435547  0.009765  0.994138  1.000000e+30  6576.043699  2350.552234
# 17703  -0.433594  0.009765  1.000470  1.000000e+30  6592.647722  2349.805547
# 18216  -0.431641  0.009765  1.006660  1.000000e+30  6487.109129  2341.018013
# 38735  -0.353516  0.007812  0.991853  1.000000e+30  5712.720843  2355.201679
# 39248  -0.351563  0.007812  0.997034  1.000000e+30  5680.132361  2350.830775
# 40274  -0.347656  0.007812  1.007220  1.000000e+30  5629.734671  2343.159463
# 44891  -0.330078  0.007812  0.993120  1.000000e+30  5408.049320  2307.152750
# 63871  -0.257813  0.005859  0.993739  1.000000e+30  5465.355864  2345.298883
# 64384  -0.255860  0.005859  0.997618  1.000000e+30  5439.922661  2341.647500
# 64897  -0.253906  0.005859  1.001460  1.000000e+30  5462.372830  2341.272346
# 65410  -0.251953  0.005859  1.005380  1.000000e+30  5439.502006  2337.708975
# 65923  -0.250000  0.005859  1.009350  1.000000e+30  5416.190314  2334.156980
# 73105  -0.222657  0.005859  1.008070  1.000000e+30  5161.009490  2289.112230
# 119787 -0.044922  0.003906  1.008870  1.000000e+30  5824.628104  2355.795506
